# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting missingno==0.5.2
#   Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Collecting xgboost==2.1.3
#   Downloading xgboost-2.1.3-py3-none-manylinux_2_28_x86_64.whl (153.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.9/153.9 MB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /root/venv/lib/python3.10/site-packages (from missingno==0.5.2->-r ./requirements.txt (line 1)) (1.25.2)
# Requirement already satisfied: matplotlib in /root/venv/lib/python3.10/site-packages (from missingno==0.5.2->-r ./requirements.txt (line 1)) (3.6.3)
# Requirement already satisfied: seaborn in /root/venv/lib/python3.10/site-packages (from missingno==0.5.2->-r ./requirements.txt (line 1)) (0.13.2)
# Requirement already satisfied: scipy in /root/venv/lib/python3.10/site-packages (from missingno==0.5.2->-r ./requirements.txt (line 1)) (1.9.3)
# Collecting nvidia-nccl-cu12
#   Downloading nvidia_nccl_cu12-2.25.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 MB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.2.1 in /root/venv/lib/python3.10/site-packages (from matplotlib->missingno==0.5.2->-r ./requirements.txt (line 1)) (3.2.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /root/venv/lib/python3.10/site-packages (from matplotlib->missingno==0.5.2->-r ./requirements.txt (line 1)) (1.4.8)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.10/site-packages (from matplotlib->missingno==0.5.2->-r ./requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in /root/venv/lib/python3.10/site-packages (from matplotlib->missingno==0.5.2->-r ./requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in /root/venv/lib/python3.10/site-packages (from matplotlib->missingno==0.5.2->-r ./requirements.txt (line 1)) (24.2)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.10/site-packages (from matplotlib->missingno==0.5.2->-r ./requirements.txt (line 1)) (4.55.4)
# Requirement already satisfied: pillow>=6.2.0 in /root/venv/lib/python3.10/site-packages (from matplotlib->missingno==0.5.2->-r ./requirements.txt (line 1)) (11.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.10/site-packages (from matplotlib->missingno==0.5.2->-r ./requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: pandas>=1.2 in /root/venv/lib/python3.10/site-packages (from seaborn->missingno==0.5.2->-r ./requirements.txt (line 1)) (2.1.4)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn->missingno==0.5.2->-r ./requirements.txt (line 1)) (2025.1)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn->missingno==0.5.2->-r ./requirements.txt (line 1)) (2024.2)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->missingno==0.5.2->-r ./requirements.txt (line 1)) (1.17.0)
# Installing collected packages: nvidia-nccl-cu12, xgboost, missingno
# Successfully installed missingno-0.5.2 nvidia-nccl-cu12-2.25.1 xgboost-2.1.3
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1d98148e-601d-4d9d-bbd4-eabbc3783172' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
